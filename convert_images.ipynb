# %%
# Import Required Libraries
from pathlib import Path
from PIL import Image

# %%
# Import Required Libraries
from pathlib import Path
from PIL import Image
